# %% [markdown]
# <a href="https://colab.research.google.com/github/faroukabdelmagied/House-Prices---Advanced-Regression-Techniques/blob/main/PYCARET_Model_Implementation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Installing Pycaret

# %%
pip install pycaret -q
# Out:
#      |████████████████████████████████| 256kB 7.7MB/s
#      |████████████████████████████████| 245kB 11.6MB/s
#      |████████████████████████████████| 14.2MB 322kB/s
#      |████████████████████████████████| 276kB 53.1MB/s
#      |████████████████████████████████| 157.5MB 92kB/s
#      |████████████████████████████████| 215kB 59.7MB/s
#      |████████████████████████████████| 1.8MB 54.8MB/s
#      |████████████████████████████████| 6.8MB 44.7MB/s
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))': /packages/20/37/bc4e0ddc30c07a96482abf1de7ed1ca54e59bba2026a33bca6d2ef286e5b/catboost-0.24.4-cp36-none-manylinux1_x86_64.whl
#      |████████████████████████████████| 65.8MB 138kB/s
#      |████████████████████████████████| 102kB 12.4MB/s
#      |████████████████████████████████| 1.7MB 44.8MB/s
#      |████████████████████████████████| 3.1MB 49.9MB/s
#      |████████████████████████████████| 81kB 11.4MB/s
#      |████████████████████████████████| 61kB 7.8MB/s
#      |████████████████████████████████| 81kB 10.1MB/s
#      |████████████████████████████████| 604kB 41.7MB/s
#      |████████████████████████████████| 163kB 48.4MB/s
#      |████████████████████████████████| 348kB 48.9MB/s
#      |████████████████████████████████| 81kB 10.0MB/s
#      |████████████████████████████████| 153kB 46.6MB/s
#      |████████████████████████████████| 1.1MB 53.0MB/s
#      |████████████████████████████████| 61kB 7.6MB/s
#      |████████████████████████████████| 296kB 48.2MB/s
#      |████████████████████████████████| 71kB 10.0MB/s
#      |████████████████████████████████| 3.2MB 43.3MB/s
#      |████████████████████████████████| 92kB 11.3MB/s
#      |████████████████████████████████| 133kB 45.3MB/s
#      |████████████████████████████████| 204kB 50.7MB/s
#      |████████████████████████████████| 481kB 46.4MB/s
#      |████████████████████████████████| 51kB 7.0MB/s
#   Building wheel for pyod (setup.py) ... done
#   Building wheel for pyLDAvis (setup.py) ... done
#   Building wheel for phik (setup.py) ... done
#   Building wheel for htmlmin (setup.py) ... done
#   Building wheel for alembic (setup.py) ... done
#   Building wheel for databricks-cli (setup.py) ... done
#   Building wheel for prometheus-flask-exporter (setup.py) ... done
#   Building wheel for Mako (setup.py) ... done
# ERROR: imbalanced-learn 0.8.0 has requirement scikit-learn>=0.24, but you'll have scikit-learn 0.23.2 which is incompatible.
# ERROR: google-colab 1.0.0 has requirement requests~=2.23.0, but you'll have requests 2.25.1 which is incompatible.
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.

# %% [markdown]
# ## Importing Packages

# %%
## Import relevant packages
from pycaret.regression import *
import pandas as pd

# %% [markdown]
# ## Loading The Data

# %%
## Loading the relvant data:
df = pd.read_csv('train.csv')

# %% [markdown]
# ## Implementing the Model

# %%
# Preparing the model:
setup(df,
      target='SalePrice',
      normalize=True,
      normalize_method='zscore',
      remove_multicollinearity=True,
      multicollinearity_threshold=0.8)
# Out:
#                                Description             Value
# 0                               session_id              8466
# 1                                   Target         SalePrice
# 2                            Original Data        (1460, 81)
# 3                           Missing Values              True
# 4                         Numeric Features                19
# 5                     Categorical Features                61
# 6                         Ordinal Features             False
# 7                High Cardinality Features             False
# 8                  High Cardinality Method              None
# 9                    Transformed Train Set       (1021, 363)
# 10                    Transformed Test Set        (439, 363)
# 11                      Shuffle Train-Test              True
# 12                     Stratify Train-Test             False
# 13                          Fold Generator             KFold
# 14                             Fold Number                10
# 15                                CPU Jobs                -1
# 16                                 Use GPU             False
# 17                          Log Experiment             False
# 18                         Experiment Name  reg-default-name
# 19                                     USI              19d7
# 20                         Imputation Type            simple
# 21          Iterative Imputation Iteration              None
# 22                         Numeric Imputer              mean
# 23      Iterative Imputation Numeric Model              None
# 24                     Categorical Imputer          constant
# 25  Iterative Imputation Categorical Model              None
# 26           Unknown Categoricals Handling    least_frequent
# 27                               Normalize              True
# 28                        Normalize Method            zscore
# 29                          Transformation             False
# 30                   Transformation Method              None
# 31                                     PCA             False
# 32                              PCA Method              None
# 33                          PCA Components              None
# 34                     Ignore Low Variance             False
# 35                     Combine Rare Levels             False
# 36                    Rare Level Threshold              None
# 37                         Numeric Binning             False
# 38                         Remove Outliers             False
# 39                      Outliers Threshold              None
# 40                Remove Multicollinearity              True
# 41             Multicollinearity Threshold               0.8
# 42                              Clustering             False
# 43                    Clustering Iteration              None
# 44                     Polynomial Features             False
# 45                       Polynomial Degree              None
# 46                    Trignometry Features             False
# 47                    Polynomial Threshold              None
# 48                          Group Features             False
# 49                       Feature Selection             False
# 50            Features Selection Threshold              None
# 51                     Feature Interaction             False
# 52                           Feature Ratio             False
# 53                   Interaction Threshold              None
# 54                        Transform Target             False
# 55                 Transform Target Method           box-cox
# ('box-cox',
#  True,
#  8466,
#  <MLUsecase.REGRESSION: 2>,
#  [],
#  [<pandas.io.formats.style.Styler at 0x7fdda832e080>],
#  -1,
#  {'cooks': 'Cooks Distance',
#   'error': 'Prediction Error',
#   'feature': 'Feature Importance',
#   'feature_all': 'Feature Importance (All)',
#   'learning': 'Learning Curve',
#   'manifold': 'Manifold Learning',
#   'parameter': 'Hyperparameters',
#   'residuals': 'Residuals',
#   'rfe': 'Feature Selection',
#   'tree': 'Decision Tree',
#   'vc': 'Validation Curve'},
#  False,
#  False,
#  {'mae': <pycaret.containers.metrics.regression.MAEMetricContainer at 0x7fdda832e518>,
#   'mape': <pycaret.containers.metrics.regression.MAPEMetricContainer at 0x7fdda832e3c8>,
#   'mse': <pycaret.containers.metrics.regression.MSEMetricContainer at 0x7fdda832e4e0>,
#   'r2': <pycaret.containers.metrics.regression.R2MetricContainer at 0x7fdda832e470>,
#   'rmse': <pycaret.containers.metrics.regression.RMSEMetricContainer at 0x7fdda832e4a8>,
#   'rmsle': <pycaret.containers.metrics.regression.RMSLEMetricContainer at 0x7fdda832e438>},
#  '19d7',
#  {'ada': <pycaret.containers.models.regression.AdaBoostRegressorContainer at 0x7fdde1167438>,
#   'ard': <pycaret.containers.models.regression.AutomaticRelevanceDeterminationContainer at 0x7fdde4ffd940>,
#   'br': <pycaret.containers.models.regression.BayesianRidgeContainer at 0x7fdde3fa8208>,
#   'catboost': <pycaret.containers.models.regression.CatBoostRegressorContainer at 0x7fdda83322e8>,
#   'dt': <pycaret.containers.models.regression.DecisionTreeRegressorContainer at 0x7fdda8334b70>,
#   'en': <pycaret.containers.models.regression.ElasticNetContainer at 0x7fdda82c8ba8>,
#   'et': <pycaret.containers.models.regression.ExtraTreesRegressorContainer at 0x7fddf3453048>,
#   'gbr': <pycaret.containers.models.regression.GradientBoostingRegressorContainer at 0x7fdde11891d0>,
#   'huber': <pycaret.containers.models.regression.HuberRegressorContainer at 0x7fdde387e668>,
#   'knn': <pycaret.containers.models.regression.KNeighborsRegressorContainer at 0x7fdda8334c50>,
#   'kr': <pycaret.containers.models.regression.KernelRidgeContainer at 0x7fdde49267b8>,
#   'lar': <pycaret.containers.models.regression.LarsContainer at 0x7fdda82c8a90>,
#   'lasso': <pycaret.containers.models.regression.LassoRegressionContainer at 0x7fdda82c8d68>,
#   'lightgbm': <pycaret.containers.models.regression.LGBMRegressorContainer at 0x7fdda8332320>,
#   'llar': <pycaret.containers.models.regression.LassoLarsContainer at 0x7fdde5013400>,
#   'lr': <pycaret.containers.models.regression.LinearRegressionContainer at 0x7fdda82c8eb8>,
#   'mlp': <pycaret.containers.models.regression.MLPRegressorContainer at 0x7fdde1137c50>,
#   'omp': <pycaret.containers.models.regression.OrthogonalMatchingPursuitContainer at 0x7fdda82c8898>,
#   'par': <pycaret.containers.models.regression.PassiveAggressiveRegressorContainer at 0x7fdde4ffdac8>,
#   'ransac': <pycaret.containers.models.regression.RANSACRegressorContainer at 0x7fdde3fa89e8>,
#   'rf': <pycaret.containers.models.regression.RandomForestRegressorContainer at 0x7fdde31d9be0>,
#   'ridge': <pycaret.containers.models.regression.RidgeRegressionContainer at 0x7fdda82c8c88>,
#   'svm': <pycaret.containers.models.regression.SVRContainer at 0x7fdda8334e10>,
#   'tr': <pycaret.containers.models.regression.TheilSenRegressorContainer at 0x7fdda8334fd0>,
#   'xgboost': <pycaret.containers.models.regression.XGBRegressorContainer at 0x7fdda83325c0>},
#  Pipeline(memory=None, steps=[('empty_step', 'passthrough')], verbose=False),
#         LotFrontage   LotArea  ...  SaleCondition_Family  SaleCondition_Normal
#  799  -4.543174e-01 -0.357540  ...                   0.0                   1.0
#  81   -1.700324e+00 -0.640090  ...                   0.0                   1.0
#  1281 -8.993196e-01 -0.268693  ...                   0.0                   1.0
#  897  -2.763165e-01 -0.376586  ...                   0.0                   0.0
#  807   3.283701e+00  1.126792  ...                   0.0                   1.0
#  ...            ...       ...  ...                   ...                   ...
#  496  -8.911715e-08  0.217189  ...                   0.0                   1.0
#  40    6.136879e-01 -0.204962  ...                   0.0                   0.0
#  1146 -8.911715e-08  0.061054  ...                   0.0                   1.0
#  861   2.131859e-01  0.105529  ...                   0.0                   1.0
#  268   3.518500e-02 -0.388934  ...                   0.0                   1.0
#
#  [1021 rows x 363 columns],
#  -1,
#  False,
#  'lightgbm',
#  799     175000.0
#  81      153500.0
#  1281    180000.0
#  897     142953.0
#  807     223500.0
#            ...
#  496     430000.0
#  40      160000.0
#  1146    180000.0
#  861     131500.0
#  268     120500.0
#  Name: SalePrice, Length: 1021, dtype: float32,
#  False,
#  'lightgbm',
#  False,
#  Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=['Id'],
#                                        ml_usecase='regression',
#                                        numerical_features=[], target='SalePrice',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numeric_st...
#                  ('dummy', Dummify(target='SalePrice')),
#                  ('fix_perfect', Remove_100(target='SalePrice')),
#                  ('clean_names', Clean_Colum_Names()),
#                  ('feature_select', 'passthrough'),
#                  ('fix_multi',
#                   Fix_multicollinearity(correlation_with_target_preference=None,
#                                         correlation_with_target_threshold=0.0,
#                                         target_variable='SalePrice',
#                                         threshold=0.8)),
#                  ('dfs', 'passthrough'), ('pca', 'passthrough')],
#           verbose=False),
#  [('Setup Config',                                Description             Value
#    0                               session_id              8466
#    1                                   Target         SalePrice
#    2                            Original Data        (1460, 81)
#    3                           Missing Values              True
#    4                         Numeric Features                19
#    5                     Categorical Features                61
#    6                         Ordinal Features             False
#    7                High Cardinality Features             False
#    8                  High Cardinality Method              None
#    9                    Transformed Train Set       (1021, 363)
#    10                    Transformed Test Set        (439, 363)
#    11                      Shuffle Train-Test              True
#    12                     Stratify Train-Test             False
#    13                          Fold Generator             KFold
#    14                             Fold Number                10
#    15                                CPU Jobs                -1
#    16                                 Use GPU             False
#    17                          Log Experiment             False
#    18                         Experiment Name  reg-default-name
#    19                                     USI              19d7
#    20                         Imputation Type            simple
#    21          Iterative Imputation Iteration              None
#    22                         Numeric Imputer              mean
#    23      Iterative Imputation Numeric Model              None
#    24                     Categorical Imputer          constant
#    25  Iterative Imputation Categorical Model              None
#    26           Unknown Categoricals Handling    least_frequent
#    27                               Normalize              True
#    28                        Normalize Method            zscore
#    29                          Transformation             False
#    30                   Transformation Method              None
#    31                                     PCA             False
#    32                              PCA Method              None
#    33                          PCA Components              None
#    34                     Ignore Low Variance             False
#    35                     Combine Rare Levels             False
#    36                    Rare Level Threshold              None
#    37                         Numeric Binning             False
#    38                         Remove Outliers             False
#    39                      Outliers Threshold              None
#    40                Remove Multicollinearity              True
#    41             Multicollinearity Threshold               0.8
#    42                              Clustering             False
#    43                    Clustering Iteration              None
#    44                     Polynomial Features             False
#    45                       Polynomial Degree              None
#    46                    Trignometry Features             False
#    47                    Polynomial Threshold              None
#    48                          Group Features             False
#    49                       Feature Selection             False
#    50            Features Selection Threshold              None
#    51                     Feature Interaction             False
#    52                           Feature Ratio             False
#    53                   Interaction Threshold              None
#    54                        Transform Target             False
#    55                 Transform Target Method           box-cox),
#   ('X_training Set',
#           LotFrontage   LotArea  ...  SaleCondition_Family  SaleCondition_Normal
#    799  -4.543174e-01 -0.357540  ...                   0.0                   1.0
#    81   -1.700324e+00 -0.640090  ...                   0.0                   1.0
#    1281 -8.993196e-01 -0.268693  ...                   0.0                   1.0
#    897  -2.763165e-01 -0.376586  ...                   0.0                   0.0
#    807   3.283701e+00  1.126792  ...                   0.0                   1.0
#    ...            ...       ...  ...                   ...                   ...
#    496  -8.911715e-08  0.217189  ...                   0.0                   1.0
#    40    6.136879e-01 -0.204962  ...                   0.0                   0.0
#    1146 -8.911715e-08  0.061054  ...                   0.0                   1.0
#    861   2.131859e-01  0.105529  ...                   0.0                   1.0
#    268   3.518500e-02 -0.388934  ...                   0.0                   1.0
#
#    [1021 rows x 363 columns]),
#   ('y_training Set', 799     175000.0
#    81      153500.0
#    1281    180000.0
#    897     142953.0
#    807     223500.0
#              ...
#    496     430000.0
#    40      160000.0
#    1146    180000.0
#    861     131500.0
#    268     120500.0
#    Name: SalePrice, Length: 1021, dtype: float32),
#   ('X_test Set',
#           LotFrontage   LotArea  ...  SaleCondition_Family  SaleCondition_Normal
#    431  -4.543174e-01 -0.526442  ...                   0.0                   0.0
#    71   -5.381544e-02 -0.315785  ...                   0.0                   1.0
#    1154 -8.911715e-08  0.322674  ...                   0.0                   1.0
#    1351 -9.315218e-03 -0.143325  ...                   0.0                   1.0
#    470  -8.911715e-08 -0.397306  ...                   0.0                   1.0
#    ...            ...       ...  ...                   ...                   ...
#    1150 -5.878181e-01 -0.244519  ...                   0.0                   1.0
#    789  -8.911715e-08  0.166225  ...                   0.0                   1.0
#    1292 -4.543174e-01 -0.420329  ...                   0.0                   1.0
#    172  -1.166321e+00 -0.555744  ...                   0.0                   1.0
#    1235  1.147691e+00  0.263234  ...                   0.0                   1.0
#
#    [439 rows x 363 columns]),
#   ('y_test Set', 431      79900.0
#    71      129500.0
#    1154    201800.0
#    1351    171000.0
#    470     212000.0
#              ...
#    1150    124000.0
#    789     187500.0
#    1292    107500.0
#    172     239000.0
#    1235    138887.0
#    Name: SalePrice, Length: 439, dtype: float32),
#   ('Transformation Pipeline', Pipeline(memory=None,
#             steps=[('dtypes',
#                     DataTypes_Auto_infer(categorical_features=[],
#                                          display_types=True, features_todrop=[],
#                                          id_columns=['Id'],
#                                          ml_usecase='regression',
#                                          numerical_features=[], target='SalePrice',
#                                          time_features=[])),
#                    ('imputer',
#                     Simple_Imputer(categorical_strategy='not_available',
#                                    fill_value_categorical=None,
#                                    fill_value_numerical=None,
#                                    numeric_st...
#                    ('dummy', Dummify(target='SalePrice')),
#                    ('fix_perfect', Remove_100(target='SalePrice')),
#                    ('clean_names', Clean_Colum_Names()),
#                    ('feature_select', 'passthrough'),
#                    ('fix_multi',
#                     Fix_multicollinearity(correlation_with_target_preference=None,
#                                           correlation_with_target_threshold=0.0,
#                                           target_variable='SalePrice',
#                                           threshold=0.8)),
#                    ('dfs', 'passthrough'), ('pca', 'passthrough')],
#             verbose=False))],
#  10,
#  None,
#  'reg-default-name',
#  KFold(n_splits=10, random_state=8466, shuffle=False),
#         LotFrontage   LotArea  ...  SaleCondition_Family  SaleCondition_Normal
#  431  -4.543174e-01 -0.526442  ...                   0.0                   0.0
#  71   -5.381544e-02 -0.315785  ...                   0.0                   1.0
#  1154 -8.911715e-08  0.322674  ...                   0.0                   1.0
#  1351 -9.315218e-03 -0.143325  ...                   0.0                   1.0
#  470  -8.911715e-08 -0.397306  ...                   0.0                   1.0
#  ...            ...       ...  ...                   ...                   ...
#  1150 -5.878181e-01 -0.244519  ...                   0.0                   1.0
#  789  -8.911715e-08  0.166225  ...                   0.0                   1.0
#  1292 -4.543174e-01 -0.420329  ...                   0.0                   1.0
#  172  -1.166321e+00 -0.555744  ...                   0.0                   1.0
#  1235  1.147691e+00  0.263234  ...                   0.0                   1.0
#
#  [439 rows x 363 columns],
#        LotFrontage   LotArea  ...  SaleCondition_Family  SaleCondition_Normal
#  0       -0.231816 -0.226729  ...                   0.0                   1.0
#  1        0.435687 -0.106384  ...                   0.0                   1.0
#  2       -0.098316  0.066286  ...                   0.0                   1.0
#  3       -0.454317 -0.111616  ...                   0.0                   0.0
#  4        0.613688  0.381278  ...                   0.0                   1.0
#  ...           ...       ...  ...                   ...                   ...
#  1455    -0.365317 -0.282507  ...                   0.0                   1.0
#  1456     0.658188  0.267734  ...                   0.0                   1.0
#  1457    -0.187316 -0.164777  ...                   0.0                   1.0
#  1458    -0.098316 -0.094140  ...                   0.0                   1.0
#  1459     0.213186 -0.071117  ...                   0.0                   1.0
#
#  [1460 rows x 363 columns],
#  [],
#  False,
#  431      79900.0
#  71      129500.0
#  1154    201800.0
#  1351    171000.0
#  470     212000.0
#            ...
#  1150    124000.0
#  789     187500.0
#  1292    107500.0
#  172     239000.0
#  1235    138887.0
#  Name: SalePrice, Length: 439, dtype: float32,
#  {'USI',
#   'X',
#   'X_test',
#   'X_train',
#   '_all_metrics',
#   '_all_models',
#   '_all_models_internal',
#   '_available_plots',
#   '_gpu_n_jobs_param',
#   '_internal_pipeline',
#   '_ml_usecase',
#   'create_model_container',
#   'data_before_preprocess',
#   'display_container',
#   'exp_name_log',
#   'experiment__',
#   'fix_imbalance_method_param',
#   'fix_imbalance_param',
#   'fold_generator',
#   'fold_groups_param',
#   'fold_param',
#   'fold_shuffle_param',
#   'gpu_param',
#   'html_param',
#   'imputation_classifier',
#   'imputation_regressor',
#   'iterative_imputation_iters_param',
#   'log_plots_param',
#   'logging_param',
#   'master_model_container',
#   'n_jobs_param',
#   'prep_pipe',
#   'pycaret_globals',
#   'seed',
#   'stratify_param',
#   'target_param',
#   'transform_target_method_param',
#   'transform_target_param',
#   'y',
#   'y_test',
#   'y_train'},
#  None,
#  0       208500.0
#  1       181500.0
#  2       223500.0
#  3       140000.0
#  4       250000.0
#            ...
#  1455    175000.0
#  1456    210000.0
#  1457    266500.0
#  1458    142125.0
#  1459    147500.0
#  Name: SalePrice, Length: 1460, dtype: float32,
#  False,
#  'SalePrice',
#  {'Bagging': <pycaret.containers.models.regression.BaggingRegressorContainer at 0x7fdda832e710>,
#   'Stacking': <pycaret.containers.models.regression.StackingRegressorContainer at 0x7fdda832e588>,
#   'Voting': <pycaret.containers.models.regression.VotingRegressorContainer at 0x7fdda832e550>,
#   'ada': <pycaret.containers.models.regression.AdaBoostRegressorContainer at 0x7fdda832f198>,
#   'ard': <pycaret.containers.models.regression.AutomaticRelevanceDeterminationContainer at 0x7fdda8330240>,
#   'br': <pycaret.containers.models.regression.BayesianRidgeContainer at 0x7fdda8330438>,
#   'catboost': <pycaret.containers.models.regression.CatBoostRegressorContainer at 0x7fdda832eac8>,
#   'dt': <pycaret.containers.models.regression.DecisionTreeRegressorContainer at 0x7fdda832f7f0>,
#   'en': <pycaret.containers.models.regression.ElasticNetContainer at 0x7fdda8330908>,
#   'et': <pycaret.containers.models.regression.ExtraTreesRegressorContainer at 0x7fdda832f400>,
#   'gbr': <pycaret.containers.models.regression.GradientBoostingRegressorContainer at 0x7fdda832f080>,
#   'huber': <pycaret.containers.models.regression.HuberRegressorContainer at 0x7fdda832fba8>,
#   'knn': <pycaret.containers.models.regression.KNeighborsRegressorContainer at 0x7fdda832f8d0>,
#   'kr': <pycaret.containers.models.regression.KernelRidgeContainer at 0x7fdda832fa90>,
#   'lar': <pycaret.containers.models.regression.LarsContainer at 0x7fdda83307b8>,
#   'lasso': <pycaret.containers.models.regression.LassoRegressionContainer at 0x7fdda8330ba8>,
#   'lightgbm': <pycaret.containers.models.regression.LGBMRegressorContainer at 0x7fdda832eb00>,
#   'llar': <pycaret.containers.models.regression.LassoLarsContainer at 0x7fdda83306a0>,
#   'lr': <pycaret.containers.models.regression.LinearRegressionContainer at 0x7fdda8330cc0>,
#   'mlp': <pycaret.containers.models.regression.MLPRegressorContainer at 0x7fdda8330cf8>,
#   'omp': <pycaret.containers.models.regression.OrthogonalMatchingPursuitContainer at 0x7fdda8330550>,
#   'par': <pycaret.containers.models.regression.PassiveAggressiveRegressorContainer at 0x7fdda832ffd0>,
#   'ransac': <pycaret.containers.models.regression.RANSACRegressorContainer at 0x7fdda832fe10>,
#   'rf': <pycaret.containers.models.regression.RandomForestRegressorContainer at 0x7fdda832f5f8>,
#   'ridge': <pycaret.containers.models.regression.RidgeRegressionContainer at 0x7fdda8330a20>,
#   'svm': <pycaret.containers.models.regression.SVRContainer at 0x7fdda832fa20>,
#   'tr': <pycaret.containers.models.regression.TheilSenRegressorContainer at 0x7fdda832fc50>,
#   'xgboost': <pycaret.containers.models.regression.XGBRegressorContainer at 0x7fdda832eda0>},
#  5,
#          Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
#  0        1          60       RL  ...        WD         Normal    208500
#  1        2          20       RL  ...        WD         Normal    181500
#  2        3          60       RL  ...        WD         Normal    223500
#  3        4          70       RL  ...        WD        Abnorml    140000
#  4        5          60       RL  ...        WD         Normal    250000
#  ...    ...         ...      ...  ...       ...            ...       ...
#  1455  1456          60       RL  ...        WD         Normal    175000
#  1456  1457          20       RL  ...        WD         Normal    210000
#  1457  1458          70       RL  ...        WD         Normal    266500
#  1458  1459          20       RL  ...        WD         Normal    142125
#  1459  1460          20       RL  ...        WD         Normal    147500
#
#  [1460 rows x 81 columns])

# %% [markdown]
# ## Comparing All Models

# %%
compare_models()
# Out:
#                                     Model           MAE           MSE  \
# catboost               CatBoost Regressor  1.587718e+04  7.928905e+08
# lightgbm  Light Gradient Boosting Machine  1.839179e+04  9.559280e+08
# xgboost         Extreme Gradient Boosting  1.912172e+04  9.796217e+08
# gbr           Gradient Boosting Regressor  1.822099e+04  9.826794e+08
# par          Passive Aggressive Regressor  1.700368e+04  1.112021e+09
# rf                Random Forest Regressor  1.948984e+04  1.126011e+09
# huber                     Huber Regressor  1.691213e+04  1.140782e+09
# br                         Bayesian Ridge  1.912103e+04  1.199741e+09
# ridge                    Ridge Regression  2.018009e+04  1.303351e+09
# omp           Orthogonal Matching Pursuit  1.832826e+04  1.402182e+09
# lasso                    Lasso Regression  1.966380e+04  1.410552e+09
# en                            Elastic Net  2.100311e+04  1.464919e+09
# et                  Extra Trees Regressor  2.230672e+04  1.475793e+09
# knn                 K Neighbors Regressor  2.247431e+04  1.503643e+09
# ada                    AdaBoost Regressor  2.628421e+04  1.499340e+09
# dt                Decision Tree Regressor  2.925972e+04  2.222733e+09
# lr                      Linear Regression  1.735252e+06  2.352616e+14
# llar         Lasso Least Angle Regression  1.706891e+09  2.848285e+21
#
#                   RMSE            R2   RMSLE       MAPE  TT (Sec)
# catboost  2.706275e+04  8.766000e-01  0.1284     0.0908     5.943
# lightgbm  3.026903e+04  8.479000e-01  0.1505     0.1067     0.192
# xgboost   3.052368e+04  8.426000e-01  0.1525     0.1107    10.604
# gbr       2.993821e+04  8.394000e-01  0.1438     0.1056     0.643
# par       3.127999e+04  8.229000e-01  0.1409     0.0988     0.991
# rf        3.239735e+04  8.223000e-01  0.1604     0.1157     2.111
# huber     3.111627e+04  8.159000e-01  0.1459     0.0985     0.267
# br        3.282678e+04  8.067000e-01  0.1589     0.1125     0.225
# ridge     3.429917e+04  7.877000e-01  0.1767     0.1188     0.032
# omp       3.439011e+04  7.738000e-01  0.1650     0.1047     0.033
# lasso     3.531126e+04  7.712000e-01  0.1954     0.1175     0.177
# en        3.669299e+04  7.710000e-01  0.1651     0.1209     0.035
# et        3.690158e+04  7.686000e-01  0.1792     0.1289     2.293
# knn       3.767763e+04  7.634000e-01  0.1812     0.1296     0.103
# ada       3.793711e+04  7.585000e-01  0.2042     0.1654     0.408
# dt        4.561356e+04  6.297000e-01  0.2310     0.1715     0.058
# lr        8.825639e+06 -4.663143e+04  1.0763    14.3937     0.321
# llar      1.721172e+10 -4.500071e+11  0.5603  7317.8695     0.404

# %% [markdown]
# ## Creating the chosen model

# %%
## Creating the model
model = create_model('ridge')
# Out:
#              MAE           MSE        RMSE      R2   RMSLE    MAPE
# 0     19461.3945  7.395203e+08  27194.1211  0.8396  0.1514  0.1143
# 1     21460.0996  1.491740e+09  38623.0508  0.7907  0.1564  0.1068
# 2     17478.9434  6.487083e+08  25469.7520  0.8807  0.1920  0.1099
# 3     21213.2793  3.736256e+09  61124.9180  0.4087  0.1958  0.1282
# 4     20307.0781  7.646599e+08  27652.4844  0.8921  0.1877  0.1203
# 5     17698.9863  5.120381e+08  22628.2598  0.8807  0.1369  0.1065
# 6     23661.1426  2.208939e+09  46999.3555  0.5911  0.2225  0.1483
# 7     19587.7793  8.756565e+08  29591.4941  0.8617  0.1737  0.1113
# 8     20403.4434  7.955840e+08  28206.0977  0.8615  0.1882  0.1287
# 9     20528.7578  1.260407e+09  35502.2148  0.8705  0.1620  0.1135
# Mean  20180.0904  1.303351e+09  34299.1748  0.7877  0.1767  0.1188
# SD     1712.6190  9.423389e+08  11265.7685  0.1520  0.0241  0.0124

# %% [markdown]
# ## Model Performance Analysis

# %%
# Analyze model:
evaluate_model(model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
# Residuals
plot_model(model, 'residuals')
